# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# URL of the CSV file
url = "https://gist.githubusercontent.com/ryanorsinger/0c702f67dfe59346cd4677cd24f7aec7/raw/429f0d47856670e57b31d1f78a1abc54c889c7ca/tips.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# URL of the CSV file
url = "https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = "https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv"
df = pd.read_csv(url)

# Step 1: Select a School
# Let's choose a random school from the dataset
selected_school = df.sample(1)

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
print(df.describe())
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
print(df.dtypes)
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
df.plot

# %%
df['School Name'].is_unique
# Out:
# False

# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
print(df.isnull().sum())
df = df.dropna()  # Drop rows with missing values
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
# Sort the DataFrame by the "Percent Scoring Below 65" column in ascending order
lowest_score_schools = df.sort_values('Percent Scoring Below 65', ascending=True)

# Display the first few rows to see schools with the lowest scores
print(lowest_score_schools.head())
# Out:
#        School DBN                             School Name School Level  \
# 20878      02M376                             NYC iSchool  High school
# 82021      18K235     P.S. 235 Janice Marie Knight School          K-8
# 183962     20K104  P.S./I.S. 104 The Fort Hamilton School          K-8
# 183963     20K104  P.S./I.S. 104 The Fort Hamilton School          K-8
# 104838     02M411       Baruch College Campus High School  High school
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 20878   Common Core English  2017           104       88.3
# 82021   Common Core English  2015            47       92.5
# 183962  Common Core Algebra  2016            28         82
# 183963  Common Core Algebra  2017            16       82.9
# 104838   Living Environment  2016            47       87.2
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 20878                        0                        0
# 82021                        0                        0
# ...

# %%
# Sort the DataFrame by the "Percent Scoring 80 or Above" column in ascending order
highest_score_schools = df.sort_values('Percent Scoring 80 or Above', ascending=True)

# Display the first few rows to see schools with the lowest scores
print(highest_score_schools.head())
# Out:
#        School DBN                       School Name School Level  \
# 56273      02M392        MANHATTAN BUSINESS ACADEMY  High school
# 71393      10X437  Fordham High School for the Arts  High school
# 173067     13K670         Benjamin Banneker Academy  High school
# 71395      10X437  Fordham High School for the Arts  High school
# 71396      10X437  Fordham High School for the Arts  High school
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# 56273              Common Core Algebra2  2016             8       56.3
# 71393   Physical Settings/Earth Science  2017            33       53.6
# 173067             Common Core Geometry  2016             9       66.6
# 71395         Physical Settings/Physics  2015            24       57.3
# 71396         Physical Settings/Physics  2015            14         55
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 56273                        6                       75
# ...

# %%
df.dropna(subset=['Number Scoring CR'], inplace=True)

# %%
df.dropna(subset=['Percent Scoring CR'], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'School Level': 'Grade Level'}, inplace=True)

# %%
df.tail()
# Out:
#        School DBN           School Name Grade Level        Regents Exam  Year  \
# 212325     84X717  Icahn Charter School         K-8  Living Environment  2015
# 212326     84X717  Icahn Charter School         K-8  Living Environment  2016
# 212327     84X717  Icahn Charter School         K-8  Living Environment  2016
# 212328     84X717  Icahn Charter School         K-8  Living Environment  2017
# 212329     84X717  Icahn Charter School         K-8  Living Environment  2017
#
#         Total Tested Mean Score Number Scoring Below 65  \
# 212325             6       79.8                       0
# 212326             8          s                       s
# 212327             5          s                       s
# 212328             6          s                       s
# 212329             4          s                       s
#
#        Percent Scoring Below 65 Number Scoring 65 or Above  \
# 212325                        0                          6
# ...

# %%
df.head()
# Out:
#   School DBN                     School Name Grade Level         Regents Exam  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt         K-8  Common Core Algebra
# 1     01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 2     01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 3     01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
# 4     01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
#
#    Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  2017             4          s                       s
# 1  2015            16       77.9                       1
# 2  2016             9         74                       1
# 3  2016             3          s                       s
# 4  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.rename(columns={'School DBN': 'DBN'}, inplace=True)

# %%
df.rename(columns={'Number Scoring Below 65': 'Scores Below 65'}, inplace=True)

# %%
df.rename(columns={'Percent Scoring Below 65': 'Percent Below 65'}, inplace=True)

# %%
df.rename(columns={'Number Scoring 65 or Above': 'Scores Above 65'}, inplace=True)

# %%
df.rename(columns={'Percent Scoring 65 or Above': 'Percent Above 65'}, inplace=True)

# %%
df.rename(columns={'Number Scoring 80 or Above': 'Scores Above 80'}, inplace=True)

# %%
df.rename(columns={'Percent Scoring 80 or Above': 'Percent Above 80'}, inplace=True)

# %%
df.drop(columns=['Number Scoring CR', 'Percent Scoring CR'], inplace=True)

# %%
df.head()
# Out:
#       DBN                     School Name Grade Level         Regents Exam  \
# 0  01M034  P.S. 034 Franklin D. Roosevelt         K-8  Common Core Algebra
# 1  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 2  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 3  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
# 4  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
#
#    Year  Total Tested Mean Score Scores Below 65 Percent Below 65  \
# 0  2017             4          s               s                s
# 1  2015            16       77.9               1              6.3
# 2  2016             9         74               1             11.1
# 3  2016             3          s               s                s
# 4  2017             2          s               s                s
#
#   Scores Above 65 Percent Above 65 Scores Above 65 Percent Above 80
# ...

# %%
df.tail()
# Out:
#            DBN           School Name Grade Level        Regents Exam  Year  \
# 212325  84X717  Icahn Charter School         K-8  Living Environment  2015
# 212326  84X717  Icahn Charter School         K-8  Living Environment  2016
# 212327  84X717  Icahn Charter School         K-8  Living Environment  2016
# 212328  84X717  Icahn Charter School         K-8  Living Environment  2017
# 212329  84X717  Icahn Charter School         K-8  Living Environment  2017
#
#         Total Tested Mean Score Scores Below 65 Percent Below 65  \
# 212325             6       79.8               0                0
# 212326             8          s               s                s
# 212327             5          s               s                s
# 212328             6          s               s                s
# 212329             4          s               s                s
#
#        Scores Above 65 Percent Above 65 Scores Above 65 Percent Above 80
# ...

# %%
df.rename(columns={'Regents Exam' : 'Exam'}, inplace=True)

# %%
df.rename(columns={'Mean Score' : 'Average'}, inplace=True)

# %%
df.head()
df.tail()
# Out:
#            DBN           School Name Grade Level                Exam  Year  \
# 212325  84X717  Icahn Charter School         K-8  Living Environment  2015
# 212326  84X717  Icahn Charter School         K-8  Living Environment  2016
# 212327  84X717  Icahn Charter School         K-8  Living Environment  2016
# 212328  84X717  Icahn Charter School         K-8  Living Environment  2017
# 212329  84X717  Icahn Charter School         K-8  Living Environment  2017
#
#         Total Tested Average Scores Below 65 Percent Below 65 Scores Above 65  \
# 212325             6    79.8               0                0               6
# 212326             8       s               s                s               s
# 212327             5       s               s                s               s
# 212328             6       s               s                s               s
# 212329             4       s               s                s               s
#
# ...

# %%
df.head()
# Out:
#       DBN                     School Name Grade Level                 Exam  \
# 0  01M034  P.S. 034 Franklin D. Roosevelt         K-8  Common Core Algebra
# 1  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 2  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 3  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
# 4  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
#
#    Year  Total Tested Average Scores Below 65 Percent Below 65  \
# 0  2017             4       s               s                s
# 1  2015            16    77.9               1              6.3
# 2  2016             9      74               1             11.1
# 3  2016             3       s               s                s
# 4  2017             2       s               s                s
#
#   Scores Above 65 Percent Above 65 Scores Above 65 Percent Above 80
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#       DBN                     School Name Grade Level                 Exam  \
# 0  01M034  P.S. 034 Franklin D. Roosevelt         K-8  Common Core Algebra
# 1  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 2  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 3  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
# 4  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
#
#    Year  Total Tested Average Scores Below 65 Percent Below 65  \
# 0  2017             4       s               s                s
# 1  2015            16    77.9               1              6.3
# 2  2016             9      74               1             11.1
# 3  2016             3       s               s                s
# 4  2017             2       s               s                s
#
#   Scores Above 65 Percent Above 65 Scores Above 65 Percent Above 80
# ...

# %%
specific_year = 2017

# %%
df['Sores Below 65']= pd.to_numeric
df['Sores Below 65'].dtype
# Out:
# dtype('O')

# %%
df.head()
# Out:
#       DBN                     School Name Grade Level                 Exam  \
# 0  01M034  P.S. 034 Franklin D. Roosevelt         K-8  Common Core Algebra
# 1  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 2  01M034  P.S. 034 Franklin D. Roosevelt         K-8   Living Environment
# 3  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
# 4  01M140          P.S. 140 Nathan Straus         K-8  Common Core Algebra
#
#    Year  Total Tested Average Scores Below 65 Percent Below 65  \
# 0  2017             4       s               s                s
# 1  2015            16    77.9               1              6.3
# 2  2016             9      74               1             11.1
# 3  2016             3       s               s                s
# 4  2017             2       s               s                s
#
#   Scores Above 65 Percent Above 65 Scores Above 65 Percent Above 80  \
# ...

# %%
df['Scores Below 65'] = pd.to_numeric(df['Scores Below 65'], errors='coerce')

# %%
print(df['Scores Below 65'].dtype)
# Out:
# float64

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Grade Level, Exam, Year, Total Tested, Average, Scores Below 65, Percent Below 65, Scores Above 65, Percent Above 65, Scores Above 65, Percent Above 80, Sores Below 65]
# Index: []

# %%
print(df.describe())
# Out:
#        Year  Total Tested  Scores Below 65  Sores Below 65
# count   0.0           0.0              0.0             0.0
# mean    NaN           NaN              NaN             NaN
# std     NaN           NaN              NaN             NaN
# min     NaN           NaN              NaN             NaN
# 25%     NaN           NaN              NaN             NaN
# 50%     NaN           NaN              NaN             NaN
# 75%     NaN           NaN              NaN             NaN
# max     NaN           NaN              NaN             NaN

# %%
sentence = "This Data set for the schools in NYC shows that there is a low percentage of students who scored below a 65 on thier exams. While there is a large percent that scored above a 65 percent. This shows that the quality of schools within NYC are doing quite well. Year after year shows a B average for each school."
print(sentence)
# Out:
# This Data set for the schools in NYC shows that there is a low percentage of students who scored below a 65 on thier exams. While there is a large percent that scored above a 65 percent. This shows that the quality of schools within NYC are doing quite well. Year after year shows a B average for each school.

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your data
data = {
    'School DBN': ['02M392', '10X437', '13K670', '10X437', '10X437', '02M376', '18K235', '20K104', '20K104', '02M411'],
    'School Name': ['MANHATTAN BUSINESS ACADEMY', 'Fordham High School for the Arts', 'Benjamin Banneker Academy', 'Fordham High School for the Arts', 'Fordham High School for the Arts', 'NYC iSchool', 'P.S. 235 Janice Marie Knight School', 'P.S./I.S. 104 The Fort Hamilton School', 'P.S./I.S. 104 The Fort Hamilton School', 'Baruch College Campus High School'],
    'Mean Score': [56.3, 53.6, 66.6, 57.3, 55, 88.3, 92.5, 82, 82.9, 87.2],
    'Year': [2016, 2017, 2016, 2015, 2015, 2017, 2015, 2016, 2017, 2016]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.bar(df['School Name'], df['Mean Score'], color='skyblue')
plt.title('Mean Scores by School')
plt.xlabel('School Name')
plt.ylabel('Mean Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
